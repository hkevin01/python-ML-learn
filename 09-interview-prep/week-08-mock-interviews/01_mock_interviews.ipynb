# %% [markdown]
# # 🎯 Week 8: Mock Interviews & Final Prep
#
# **Goal:** Simulate real interview conditions and finalize your preparation.
#
# ---
#
# ## 📅 Week 8 Schedule
#
# | Day | Focus | Duration |
# |-----|-------|----------|
# | 1-2 | Technical Mock Interviews | 2-3 hrs |
# | 3-4 | System Design & ML Design | 2-3 hrs |
# | 5 | Behavioral Prep | 1-2 hrs |
# | 6-7 | Final Review & Rest | 1-2 hrs |
#
# ---

# %% [markdown]
# ## 🔥 Mock Interview 1: Coding (45 min)
#
# **Rules:**
# - Set a timer for 45 minutes
# - No looking at solutions until done
# - Talk through your approach out loud
# - Write clean, production-ready code
#
# ---

# %%
from typing import List, Dict, Optional, Tuple
import numpy as np
import pandas as pd
print("Ready for mock interview!")

# %% [markdown]
# ### Problem 1: Merge Intervals (15 min)
#
# Given an array of intervals, merge all overlapping intervals.

# %%
def merge_intervals(intervals: List[List[int]]) -> List[List[int]]:
    """
    Merge overlapping intervals.
    
    Example:
        Input: [[1,3],[2,6],[8,10],[15,18]]
        Output: [[1,6],[8,10],[15,18]]
    """
    # YOUR CODE HERE
    pass


# Test cases
print(merge_intervals([[1,3],[2,6],[8,10],[15,18]]))  # [[1,6],[8,10],[15,18]]
print(merge_intervals([[1,4],[4,5]]))  # [[1,5]]

# %% [markdown]
# ### Problem 2: Design Hit Counter (15 min)
#
# Design a hit counter that counts hits in the past 5 minutes.

# %%
class HitCounter:
    """
    Design a hit counter that counts hits in the past 5 minutes (300 seconds).
    
    hit(timestamp): Record a hit at given timestamp (in seconds)
    getHits(timestamp): Return number of hits in past 300 seconds
    
    Timestamps are in increasing order.
    """
    
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def hit(self, timestamp: int) -> None:
        # YOUR CODE HERE
        pass
    
    def getHits(self, timestamp: int) -> int:
        # YOUR CODE HERE
        pass


# Test
counter = HitCounter()
counter.hit(1)
counter.hit(2)
counter.hit(3)
print(counter.getHits(4))   # 3
counter.hit(300)
print(counter.getHits(300)) # 4
print(counter.getHits(301)) # 3 (hit at 1 expired)

# %% [markdown]
# ### Problem 3: Evaluate Reverse Polish Notation (15 min)
#
# Evaluate an expression in Reverse Polish Notation.

# %%
def eval_rpn(tokens: List[str]) -> int:
    """
    Evaluate Reverse Polish Notation expression.
    
    Example:
        ["2","1","+","3","*"] = ((2 + 1) * 3) = 9
        ["4","13","5","/","+"] = (4 + (13 / 5)) = 6
    
    Note: Division truncates toward zero.
    """
    # YOUR CODE HERE
    pass


# Test
print(eval_rpn(["2","1","+","3","*"]))  # 9
print(eval_rpn(["4","13","5","/","+"]))  # 6
print(eval_rpn(["10","6","9","3","+","-11","*","/","*","17","+","5","+"]))  # 22

# %% [markdown]
# ---
# ## Solutions (Don't look until you're done!)

# %%
# Solution 1: Merge Intervals
def merge_intervals_solution(intervals: List[List[int]]) -> List[List[int]]:
    if not intervals:
        return []
    
    # Sort by start time
    intervals.sort(key=lambda x: x[0])
    
    merged = [intervals[0]]
    
    for start, end in intervals[1:]:
        last_end = merged[-1][1]
        
        if start <= last_end:  # Overlapping
            merged[-1][1] = max(last_end, end)
        else:
            merged.append([start, end])
    
    return merged


# Solution 2: Hit Counter
from collections import deque

class HitCounterSolution:
    def __init__(self):
        self.hits = deque()  # (timestamp, count)
    
    def hit(self, timestamp: int) -> None:
        if self.hits and self.hits[-1][0] == timestamp:
            self.hits[-1][1] += 1
        else:
            self.hits.append([timestamp, 1])
    
    def getHits(self, timestamp: int) -> int:
        # Remove expired hits
        while self.hits and self.hits[0][0] <= timestamp - 300:
            self.hits.popleft()
        
        return sum(count for _, count in self.hits)


# Solution 3: Evaluate RPN
def eval_rpn_solution(tokens: List[str]) -> int:
    stack = []
    operators = {'+', '-', '*', '/'}
    
    for token in tokens:
        if token in operators:
            b, a = stack.pop(), stack.pop()
            if token == '+':
                result = a + b
            elif token == '-':
                result = a - b
            elif token == '*':
                result = a * b
            else:  # division
                result = int(a / b)  # Truncate toward zero
            stack.append(result)
        else:
            stack.append(int(token))
    
    return stack[0]

print("Solutions loaded!")

# %% [markdown]
# ---
# ## 🧠 Mock Interview 2: ML System Design (45 min)
#
# **Scenario:** Design a fraud detection system for an e-commerce platform.
#
# ### Your Task:
# Walk through the complete ML system design.
#
# ---

# %% [markdown]
# ### ML Design Framework
#
# **1. Clarify Requirements (5 min)**
# - What type of fraud? (payment, account, etc.)
# - Latency requirements? (real-time vs batch)
# - Scale? (transactions per second)
# - What actions on fraud detection?
#
# **2. Define Metrics (5 min)**
# - Business metrics: False positive cost, fraud loss
# - ML metrics: Precision/Recall tradeoff, AUC-ROC
# - Online metrics: Latency, throughput
#
# **3. Data (10 min)**
# - What data is available?
# - Label quality and availability
# - Feature engineering ideas
# - Data pipelines
#
# **4. Model Selection (10 min)**
# - Baseline: Rules-based system
# - ML approaches: Gradient Boosting, Neural Nets
# - Ensemble strategies
# - Model interpretability needs
#
# **5. System Architecture (10 min)**
# - Online vs offline components
# - Feature store design
# - Model serving infrastructure
# - Monitoring and alerting
#
# **6. Challenges & Solutions (5 min)**
# - Class imbalance
# - Concept drift
# - Adversarial attacks
# - Cold start problem

# %%
# Your ML Design Notes (write here)
ml_design = {
    "requirements": {
        # Fill in your clarifications
    },
    "metrics": {
        "business": [],
        "ml": [],
        "online": []
    },
    "data": {
        "sources": [],
        "features": [],
        "labels": ""
    },
    "model": {
        "baseline": "",
        "primary": "",
        "reasoning": ""
    },
    "architecture": {
        "components": [],
        "serving": ""
    },
    "challenges": {
        # Challenge: Solution pairs
    }
}

# %% [markdown]
# ---
# ## 🎤 Mock Interview 3: Behavioral (30 min)
#
# Practice the STAR method for these common questions.
#
# ---

# %% [markdown]
# ### STAR Method
#
# - **S**ituation: Set the context
# - **T**ask: Describe your responsibility
# - **A**ction: Explain what you did
# - **R**esult: Share the outcome (with metrics!)
#
# ---
#
# ### Common Questions:
#
# **1. Tell me about a challenging ML project.**
# - What made it challenging?
# - How did you overcome obstacles?
# - What was the impact?
#
# **2. Describe a time you had to convince stakeholders.**
# - What was the disagreement?
# - How did you present your case?
# - What was the outcome?
#
# **3. Tell me about a failure and what you learned.**
# - What went wrong?
# - What did you do about it?
# - How did you prevent it from happening again?
#
# **4. How do you prioritize when everything is urgent?**
# - Framework for prioritization
# - Specific example
# - Result
#
# **5. Describe your ideal work environment.**
# - What motivates you?
# - How do you collaborate?
# - What's your working style?

# %%
# Prepare your STAR stories
behavioral_stories = {
    "challenging_project": {
        "situation": "",
        "task": "",
        "action": "",
        "result": ""
    },
    "convincing_stakeholders": {
        "situation": "",
        "task": "",
        "action": "",
        "result": ""
    },
    "failure_and_learning": {
        "situation": "",
        "task": "",
        "action": "",
        "result": ""
    }
}

print("Fill in your STAR stories above!")

# %% [markdown]
# ---
# ## ✅ Final Checklist
#
# ### Technical Skills
# - [ ] Python fundamentals (data structures, OOP)
# - [ ] NumPy/Pandas operations
# - [ ] Classical ML algorithms (how they work, when to use)
# - [ ] Deep learning basics (architectures, training)
# - [ ] Feature engineering techniques
# - [ ] Model evaluation and metrics
# - [ ] Common coding patterns (sliding window, two pointers, etc.)
# - [ ] SQL window functions and joins
#
# ### ML Concepts
# - [ ] Bias-variance tradeoff
# - [ ] Overfitting/underfitting diagnosis
# - [ ] Cross-validation strategies
# - [ ] Handling imbalanced data
# - [ ] Feature selection methods
# - [ ] Regularization techniques
# - [ ] Ensemble methods
# - [ ] Gradient descent variants
#
# ### System Design
# - [ ] ML system components
# - [ ] Feature stores
# - [ ] Model serving patterns
# - [ ] A/B testing
# - [ ] Monitoring and drift detection
# - [ ] Scaling considerations
#
# ### Soft Skills
# - [ ] STAR stories prepared
# - [ ] Questions for interviewer ready
# - [ ] Company research done
# - [ ] Clear communication practice

# %% [markdown]
# ---
# ## 📝 Questions to Ask Interviewers
#
# ### About the Role
# 1. What does a typical project lifecycle look like?
# 2. How do you measure success for ML projects?
# 3. What's the biggest technical challenge the team is facing?
#
# ### About the Team
# 1. How is the ML team structured?
# 2. How do you collaborate with product and engineering?
# 3. What's the onboarding process like?
#
# ### About the Company
# 1. What are the biggest ML opportunities in the next year?
# 2. How do you balance research vs production work?
# 3. What does career growth look like here?
#
# ### Red Flags to Watch For
# - Unclear ML strategy or roadmap
# - No production ML yet after years of trying
# - Very high turnover
# - Unrealistic timelines mentioned
# - No mention of data infrastructure

# %% [markdown]
# ---
# ## 🎯 Day Before Interview
#
# ### Do:
# - [ ] Review your resume - be ready to discuss any project
# - [ ] Light review of key concepts (no cramming!)
# - [ ] Prepare your setup (video, audio, lighting)
# - [ ] Get good sleep
# - [ ] Prepare snacks and water
#
# ### Don't:
# - [ ] Stay up late studying
# - [ ] Try to learn new concepts
# - [ ] Stress about edge cases you don't know
#
# ---
#
# ## �� Day Of Interview
#
# ### Before:
# - [ ] Test your setup 30 minutes early
# - [ ] Have water and notepad ready
# - [ ] Review your STAR stories
# - [ ] Take deep breaths, stay calm
#
# ### During:
# - [ ] Listen carefully to the question
# - [ ] Ask clarifying questions
# - [ ] Think out loud
# - [ ] It's OK to pause and think
# - [ ] If stuck, explain your thinking
#
# ### After:
# - [ ] Send thank-you email within 24 hours
# - [ ] Write down questions you struggled with
# - [ ] Reflect on what went well

# %% [markdown]
# ---
# ## 🎉 Congratulations!
#
# You've completed the 8-week AI/ML Interview Prep curriculum!
#
# ### What You've Learned:
# - Week 1: Python fundamentals
# - Week 2: Classical ML algorithms
# - Week 3: Feature engineering & preprocessing
# - Week 4: End-to-end ML projects
# - Week 5: NLP basics & model deployment
# - Week 6: Debugging & ML reasoning
# - Week 7: Coding challenges & communication
# - Week 8: Mock interviews & final prep
#
# ### Next Steps:
# 1. Continue practicing on LeetCode/HackerRank
# 2. Build more projects for your portfolio
# 3. Contribute to open source ML projects
# 4. Stay current with ML papers and blogs
#
# ---
#
# **Good luck with your interviews! You've got this! 🚀**
